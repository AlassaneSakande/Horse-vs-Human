# %% [markdown]
# # Human vs Horse prediction

# %% [markdown]
# ## In this project we will predict if a given image represents a human or horse

# %% [markdown]
# ### Starting by downloading the dataset

# %%
# !wget https://storage.googleapis.com/tensorflow-1-public/course2/week3/horse-or-human.zip
# Out:
# --2022-07-08 14:27:55--  https://storage.googleapis.com/tensorflow-1-public/course2/week3/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 216.58.209.240, 216.58.204.112, 216.58.206.240, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|216.58.209.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip’
#
# horse-or-human.zip  100%[===================>] 142.65M  2.46MB/s    in 57s
#
# 2022-07-08 14:28:53 (2.50 MB/s) - ‘horse-or-human.zip’ saved [149574867/149574867]

# %% [markdown]
# ### We are unziping our downloaded dataset

# %%
import zipfile

# Unzip the dataset
local_zip = './horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./horse-or-human')
zip_ref.close()

# %% [markdown]
# ### It's time to set our training path for both human and horses

# %%
import os

# Directory with our training horse pictures
train_horse_dir = os.path.join('./horse-or-human/horses')

# Directory with our training human pictures
train_human_dir = os.path.join('./horse-or-human/humans')

# %% [markdown]
# ### Let's print of the first 10 images for each directory

# %%
train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])

train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])
# Out:
# ['horse03-0.png', 'horse15-4.png', 'horse40-6.png', 'horse04-6.png', 'horse50-4.png', 'horse20-5.png', 'horse30-8.png', 'horse29-1.png', 'horse13-6.png', 'horse39-1.png']
# ['human02-12.png', 'human08-11.png', 'human04-25.png', 'human01-29.png', 'human05-16.png', 'human11-03.png', 'human05-02.png', 'human04-16.png', 'human03-21.png', 'human02-24.png']

# %% [markdown]
# ### We can preview the number of images for human and horses

# %%
print('total training horse images:', len(os.listdir(train_horse_dir)))
print('total training human images:', len(os.listdir(train_human_dir)))
# Out:
# total training horse images: 500
# total training human images: 527

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %% [markdown]
# ### Now we're reading some images

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ### Building the model

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 64)        36928
# ...

# %% [markdown]
# ### Defining optimizer for training

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

# %% [markdown]
# ### Applying data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        './horse-or-human/',  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.

# %% [markdown]
# ### Train the model

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=15,
      verbose=1)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 87s 10s/step - loss: 0.8570 - accuracy: 0.5094
# Epoch 2/15
# 8/8 [==============================] - 88s 10s/step - loss: 0.9815 - accuracy: 0.5787
# Epoch 3/15
# 8/8 [==============================] - 82s 10s/step - loss: 0.4835 - accuracy: 0.7260
# Epoch 4/15
# 8/8 [==============================] - 86s 10s/step - loss: 0.2484 - accuracy: 0.9057
# Epoch 5/15
# 8/8 [==============================] - 83s 10s/step - loss: 0.2351 - accuracy: 0.9112
# Epoch 6/15
# 8/8 [==============================] - 86s 10s/step - loss: 0.5779 - accuracy: 0.8554
# Epoch 7/15
# 8/8 [==============================] - 96s 12s/step - loss: 0.1387 - accuracy: 0.9478
# Epoch 8/15
# 8/8 [==============================] - 82s 10s/step - loss: 0.1076 - accuracy: 0.9569
# Epoch 9/15
# 8/8 [==============================] - 97s 12s/step - loss: 0.1795 - accuracy: 0.9303
# Epoch 10/15
# ...

# %% [markdown]
# ### Here we can clearly see that we've achieved a great accuracy but the problem is our data is not too much it seems we overfit on it. Because we miss convergence, Accuracy get better and then in a worse way : 0.99 --> 0.799 . We must think about augmenting our data or use regularization, also dropout layer can help

# %% [markdown]
# ### Let's test on some images and then come back to our overfitting problem

# %%
import numpy as np
from keras.preprocessing import image

# providing a local path to the image
path = "/home/alassane/Pictures/Untitled Folder/Nokota_Horses_cropped.jpg"

img = image.load_img(path, target_size=(300, 300))

# Convert pixels to array of pixels
x = image.img_to_array(img)

# Normalizing our pixels so they must be in a range 0-1
x /= 255

x = np.expand_dims(x, axis=0)

image = np.vstack([x])
classe = model.predict(image, batch_size=10)  
print(classe)
    
if classe>0.5:
    print(" is a human")
else:
    print(" is a horse")
# Out:
# [[0.01046008]]
#  is a horse

# %% [markdown]
# ### At a first glance we can say we've done because the model has correctly the image but after a few try with different images you'll start noticing the imperfections of our model

# %% [markdown]
# # We reason why we must deal with overfitting
